# %% [markdown]
# ### Import & Process data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# 导入 alpha_utils 模块中的函数
import sys
from pathlib import Path
project_dir = Path().resolve().parent
sys.path.append(str(project_dir))
from alpha_utils import *

sns.set_style('whitegrid')
pd.options.display.float_format = '{:,.2f}'.format

# %%
data = pd.read_pickle('../data/merged_df.pkl')
print(f"# Symbols: {len(data.index.unique('symbol')):,.0f} | # Dates: {len(data.index.unique('Date')):,.0f}")
data.info()
# Out:
# # Symbols: 20 | # Dates: 6,769
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 182763 entries, ('ADAUSDT', Timestamp('2024-07-01 00:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-09 00:00:00+0000', tz='UTC'))
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Open          182763 non-null  float64
#  1   High          182763 non-null  float64
#  2   Low           182763 non-null  float64
#  3   Close         182763 non-null  float64
#  4   Volume        182763 non-null  float64
#  5   id            175994 non-null  object
#  6   symbol_meta   175994 non-null  object
#  7   name          175994 non-null  object
#  8   market_cap    175994 non-null  float64
#  9   total_volume  175994 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 14.5+ MB

# %%
print("Symbols include: ", list(data.index.levels[0]))
# Out:
# Symbols include:  ['ADAUSDT', 'BNBUSDT', 'BTCUSDT', 'EOSUSDT', 'ETCUSDT', 'ETHUSDT', 'ICXUSDT', 'IOTAUSDT', 'LINKUSDT', 'LTCUSDT', 'NEOUSDT', 'NULSUSDT', 'ONTUSDT', 'QTUMUSDT', 'TRXUSDT', 'TUSDUSDT', 'USDCUSDT', 'VETUSDT', 'XLMUSDT', 'XRPUSDT']

# %%
# remove duplicates
duplicates = data.index.duplicated()
print(data[duplicates].index.unique('symbol'))
data = data[~data.index.duplicated()]
data.info()
# Out:
# Index(['EOSUSDT', 'ETHUSDT', 'USDCUSDT'], dtype='object', name='symbol')
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 135380 entries, ('ADAUSDT', Timestamp('2024-07-01 00:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-09 00:00:00+0000', tz='UTC'))
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Open          135380 non-null  float64
#  1   High          135380 non-null  float64
#  2   Low           135380 non-null  float64
#  3   Close         135380 non-null  float64
#  4   Volume        135380 non-null  float64
#  5   id            128611 non-null  object
#  6   symbol_meta   128611 non-null  object
#  7   name          128611 non-null  object
#  8   market_cap    128611 non-null  float64
#  9   total_volume  128611 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 10.8+ MB

# %%
by_symbol = data.groupby(level='symbol')

# %%
# Forward returns
T = [1, 2, 3, 4, 5, 12, 24, 48, 72]
for t in T:
    data[f'ret_{t:02}'] = - by_symbol.Close.pct_change(-t)

# %%
# Backward returns (pct change)
T = [1, 2, 3, 4, 5, 12, 24, 48, 72]
for t in T:
    data[f'change_{t:02}'] = by_symbol.Close.pct_change(t)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 135380 entries, ('ADAUSDT', Timestamp('2024-07-01 00:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-09 00:00:00+0000', tz='UTC'))
# Data columns (total 28 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Open          135380 non-null  float64
#  1   High          135380 non-null  float64
#  2   Low           135380 non-null  float64
#  3   Close         135380 non-null  float64
#  4   Volume        135380 non-null  float64
#  5   id            128611 non-null  object
#  6   symbol_meta   128611 non-null  object
#  7   name          128611 non-null  object
#  8   market_cap    128611 non-null  float64
#  9   total_volume  128611 non-null  float64
#  10  ret_01        135360 non-null  float64
#  11  ret_02        135340 non-null  float64
#  12  ret_03        135320 non-null  float64
#  13  ret_04        135300 non-null  float64
#  14  ret_05        135280 non-null  float64
#  15  ret_12        135140 non-null  float64
#  16  ret_24        134900 non-null  float64
#  17  ret_48        134420 non-null  float64
#  18  ret_72        133940 non-null  float64
#  19  change_01     135360 non-null  float64
#  20  change_02     135340 non-null  float64
#  21  change_03     135320 non-null  float64
#  22  change_04     135300 non-null  float64
#  23  change_05     135280 non-null  float64
#  24  change_12     135140 non-null  float64
#  25  change_24     134900 non-null  float64
#  26  change_48     134420 non-null  float64
#  27  change_72     133940 non-null  float64
# dtypes: float64(25), object(3)
# memory usage: 29.4+ MB

# %%
o = data.Open.unstack('symbol')
h = data.High.unstack('symbol')
l = data.Low.unstack('symbol')
c = data.Close.unstack('symbol')
v = data.Volume.unstack('symbol')
vwap = o.add(h).add(l).add(c).div(4)
adv20 = v.rolling(20).mean()
r = data.change_01.unstack('symbol') # return/change over the last window

# %% [markdown]
# ### Alpha 028
# ```
# -rank((ts_std(abs((close - open)), 5) + (close - open)) +
#             ts_corr(close, open,10))
# ```

# %%
alpha = 28

# %%
def alpha028(h, l, c, adv20):
    """scale(((ts_corr(adv20, low, 5) + (high + low) / 2) - close))"""
    return (scale(ts_corr(adv20, l, 12)
                  .replace([-np.inf, np.inf], 0)
                  .add(h.add(l).div(2).sub(c)))
            .stack('symbol')
            .swaplevel())

# %%
ret_col = [c for c in data.columns if 'ret_' in c] + ['Close']
alphas = data[ret_col].copy()
alphas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 135380 entries, ('ADAUSDT', Timestamp('2024-07-01 00:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-09 00:00:00+0000', tz='UTC'))
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ret_01  135360 non-null  float64
#  1   ret_02  135340 non-null  float64
#  2   ret_03  135320 non-null  float64
#  3   ret_04  135300 non-null  float64
#  4   ret_05  135280 non-null  float64
#  5   ret_12  135140 non-null  float64
#  6   ret_24  134900 non-null  float64
#  7   ret_48  134420 non-null  float64
#  8   ret_72  133940 non-null  float64
#  9   Close   135380 non-null  float64
# dtypes: float64(10)
# memory usage: 10.8+ MB

# %%
# %%time
alphas[f'{alpha:03}'] = alpha028(h, l, c, adv20)

# %%
alphas.dropna(inplace=True)

# %%
alphas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 133060 entries, ('ADAUSDT', Timestamp('2024-07-02 06:00:00+0000', tz='UTC')) to ('XRPUSDT', Timestamp('2025-04-06 00:00:00+0000', tz='UTC'))
# Data columns (total 11 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ret_01  133060 non-null  float64
#  1   ret_02  133060 non-null  float64
#  2   ret_03  133060 non-null  float64
#  3   ret_04  133060 non-null  float64
#  4   ret_05  133060 non-null  float64
#  5   ret_12  133060 non-null  float64
#  6   ret_24  133060 non-null  float64
#  7   ret_48  133060 non-null  float64
#  8   ret_72  133060 non-null  float64
#  9   Close   133060 non-null  float64
#  10  028     133060 non-null  float64
# dtypes: float64(11)
# memory usage: 11.6+ MB

# %%
alphas[f"{alpha:003}"].describe()
# Out:
# count   133,060.00
# mean         -0.00
# std           0.19
# min          -0.99
# 25%          -0.00
# 50%          -0.00
# 75%           0.00
# max           0.99
# Name: 028, dtype: float64

# %% [markdown]
# #### Alpha trend visualization

# %%
# 假设数据已经在 df 中
symbols = ['BTCUSDT', 'ETHUSDT', 'XRPUSDT']

# 随机选取3个24小时的时间段
np.random.seed(42)
timestamps = alphas.index.get_level_values('Date').unique()
start_indices = np.random.choice(len(timestamps) - 24, size=3, replace=False)

time_ranges = [(timestamps[i], timestamps[i+23]) for i in start_indices]

# 开始绘图
for symbol in symbols:
    fig, axs = plt.subplots(3, 1, figsize=(8, 6), sharex=False)
    fig.suptitle(f'{symbol} - alpha{alpha:03} vs Close', fontsize=16)

    for idx, (start, end) in enumerate(time_ranges):
        temp_df = alphas.loc[symbol].loc[start:end]

        ax1 = axs[idx]
        ax1.plot(temp_df.index, temp_df[f'{alpha:03}'], label=f'alpha{alpha:03}', color='tab:blue', marker='o')
        ax1.set_ylabel(f'alpha{alpha:03}', color='tab:blue')
        ax1.tick_params(axis='y', labelcolor='tab:blue')

        ax2 = ax1.twinx()
        ax2.plot(temp_df.index, temp_df['Close'], label='Close', color='tab:red', marker='x')
        ax2.set_ylabel('Close', color='tab:red')
        ax2.tick_params(axis='y', labelcolor='tab:red')

        ax1.set_title(f'Time range: {start.strftime("%Y-%m-%d %H:%M")} - {end.strftime("%Y-%m-%d %H:%M")}', fontsize=12)

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %% [markdown]
# #### Distribution visualization

# %%
sns.histplot(alphas[f"{alpha:03}"])
# Out:
# <Axes: xlabel='028', ylabel='Count'>

# %%
g = sns.jointplot(x=f"{alpha:03}", y='ret_01', data=alphas)

# %% [markdown]
# #### Correlation with future return

# %%
for c in ret_col:
    print(f"Corr between alpha{alpha:03} and {c} is:", alphas[f"{alpha:03}"].corr(alphas[c]))
# Out:
# Corr between alpha028 and ret_01 is: 0.004750717906740617
# Corr between alpha028 and ret_02 is: 0.004202899681167874
# Corr between alpha028 and ret_03 is: 0.005379641233175244
# Corr between alpha028 and ret_04 is: 0.004717560043595343
# Corr between alpha028 and ret_05 is: 0.003822617067906925
# Corr between alpha028 and ret_12 is: 0.001718138895421971
# Corr between alpha028 and ret_24 is: 0.0014839378928380076
# Corr between alpha028 and ret_48 is: 0.0006765630051379879
# Corr between alpha028 and ret_72 is: -0.0008148309013362811
# Corr between alpha028 and Close is: -0.01901509322721762

# %%
analysis_cols = ['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72', f'{alpha:03}']

# 初始化一个空的DataFrame用于存储每个币种的相关系数
symbols = alphas.index.get_level_values('symbol').unique()
correlation_results = pd.DataFrame(index=['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72'], 
                                   columns=symbols)

# 逐个币种计算相关系数
for symbol in symbols:
    temp_df = alphas.loc[symbol, analysis_cols].dropna()
    correlations = temp_df.corr()[f'{alpha:03}'].drop(f'{alpha:03}')
    correlation_results[symbol] = correlations

# 可视化热力图
plt.figure(figsize=(12, 7))
sns.heatmap(correlation_results.astype(float), annot=True, cmap='coolwarm', center=0)
plt.title(f'Correlation between Alpha{alpha:03} and Future Returns by Crypto')
plt.xlabel('Crypto Symbol')
plt.ylabel('Return Period')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Regression

# %%
X = sm.add_constant(alphas[f"{alpha:03}"])
model = sm.OLS(alphas['ret_01'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ret_01   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     3.003
# Date:                Sat, 26 Apr 2025   Prob (F-statistic):             0.0831
# Time:                        15:54:16   Log-Likelihood:             4.2198e+05
# No. Observations:              133060   AIC:                        -8.440e+05
# Df Residuals:                  133058   BIC:                        -8.439e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.688e-05   2.78e-05     -2.044      0.041      -0.000   -2.34e-06
# 028            0.0003      0.000      1.733      0.083   -3.35e-05       0.001
# ==============================================================================
# Omnibus:                    40276.337   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6549554.442
# Skew:                           0.208   Prob(JB):                         0.00
# Kurtosis:                      37.368   Cond. No.                         5.31
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
residuals = model.resid

# 1. 绘制直方图和 KDE 曲线
plt.figure(figsize=(10,6))
sns.histplot(residuals, bins=30, kde=True)
plt.xlabel("Residuals")
plt.title("Distribution of Model Residuals")
plt.show()

# 2. 绘制 Q-Q 图，检查正态性
sm.qqplot(residuals, line='s')
plt.title("Q-Q Plot of Model Residuals")
plt.show()

# %% [markdown]
# ### Evaluation for BTC

# %%
btc_data = alphas.loc['BTCUSDT']
btc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6667 entries, 2024-07-02 06:00:00+00:00 to 2025-04-06 00:00:00+00:00
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ret_01  6667 non-null   float64
#  1   ret_02  6667 non-null   float64
#  2   ret_03  6667 non-null   float64
#  3   ret_04  6667 non-null   float64
#  4   ret_05  6667 non-null   float64
#  5   ret_12  6667 non-null   float64
#  6   ret_24  6667 non-null   float64
#  7   ret_48  6667 non-null   float64
#  8   ret_72  6667 non-null   float64
#  9   Close   6667 non-null   float64
#  10  028     6667 non-null   float64
# dtypes: float64(11)
# memory usage: 625.0 KB

# %%
sns.histplot(btc_data[f"{alpha:03}"])
# Out:
# <Axes: xlabel='028', ylabel='Count'>

# %%
for c in ret_col:
    print(f"Corr between alpha{alpha:03} and {c} is:", btc_data[f"{alpha:03}"].corr(btc_data[c]))
# Out:
# Corr between alpha028 and ret_01 is: 0.0360010631089397
# Corr between alpha028 and ret_02 is: 0.030551486455851644
# Corr between alpha028 and ret_03 is: 0.041602964235717646
# Corr between alpha028 and ret_04 is: 0.03648948044748912
# Corr between alpha028 and ret_05 is: 0.0294725872158322
# Corr between alpha028 and ret_12 is: 0.010357126705213304
# Corr between alpha028 and ret_24 is: 0.007652992005426554
# Corr between alpha028 and ret_48 is: 0.0038657864413992257
# Corr between alpha028 and ret_72 is: -0.0017231194653159485
# Corr between alpha028 and Close is: 0.0012903712174586518

# %%
btc_data.index = pd.to_datetime(btc_data.index)

# 创建月份的分组标签（格式如 '2024-07'）
btc_data['month'] = btc_data.index.to_period('M').astype(str)

# 需要分析的收益列
ret_columns = ['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72']

# 初始化一个DataFrame用于存储相关性结果
months = sorted(btc_data['month'].unique())
correlation_matrix = pd.DataFrame(index=ret_columns, columns=months)

# 按月份计算相关性
for month in months:
    temp_df = btc_data[btc_data['month'] == month]
    for ret in ret_columns:
        corr_value = temp_df[[f'{alpha:03}', ret]].corr().iloc[0, 1]
        correlation_matrix.loc[ret, month] = corr_value

# 转换数据类型为float，方便绘图
correlation_matrix = correlation_matrix.astype(float)

# 使用heatmap可视化
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title(f'Monthly Correlation between Alpha{alpha:03} and Returns for BTC', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Return Columns', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_16204\1316720417.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   btc_data['month'] = btc_data.index.to_period('M').astype(str)
# C:\Users\elisa\AppData\Local\Temp\ipykernel_16204\1316720417.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   btc_data['month'] = btc_data.index.to_period('M').astype(str)

# %%
X = sm.add_constant(btc_data[f"{alpha:03}"])
model = sm.OLS(btc_data['ret_01'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ret_01   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     8.650
# Date:                Sat, 26 Apr 2025   Prob (F-statistic):            0.00328
# Time:                        15:54:27   Log-Likelihood:                 24898.
# No. Observations:                6667   AIC:                        -4.979e+04
# Df Residuals:                    6665   BIC:                        -4.978e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.009e-05   7.08e-05      0.425      0.671      -0.000       0.000
# 028            0.0002   8.47e-05      2.941      0.003    8.31e-05       0.000
# ==============================================================================
# Omnibus:                     1145.073   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            21159.296
# Skew:                          -0.248   Prob(JB):                         0.00
# Kurtosis:                      11.713   Cond. No.                         1.20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Evaluation for ETH

# %%
eth_data = alphas.loc['ETHUSDT']
eth_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6667 entries, 2024-07-02 06:00:00+00:00 to 2025-04-06 00:00:00+00:00
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ret_01  6667 non-null   float64
#  1   ret_02  6667 non-null   float64
#  2   ret_03  6667 non-null   float64
#  3   ret_04  6667 non-null   float64
#  4   ret_05  6667 non-null   float64
#  5   ret_12  6667 non-null   float64
#  6   ret_24  6667 non-null   float64
#  7   ret_48  6667 non-null   float64
#  8   ret_72  6667 non-null   float64
#  9   Close   6667 non-null   float64
#  10  028     6667 non-null   float64
# dtypes: float64(11)
# memory usage: 625.0 KB

# %%
sns.histplot(eth_data[f"{alpha:03}"])
# Out:
# <Axes: xlabel='028', ylabel='Count'>

# %%
for c in ret_col:
    print(f"Corr between alpha{alpha:03} and {c} is:", eth_data[f"{alpha:03}"].corr(eth_data[c]))
# Out:
# Corr between alpha028 and ret_01 is: 0.012257802237320203
# Corr between alpha028 and ret_02 is: 0.015695656273057655
# Corr between alpha028 and ret_03 is: 0.007976879433065354
# Corr between alpha028 and ret_04 is: 0.003153786763361122
# Corr between alpha028 and ret_05 is: 0.0036986918496405663
# Corr between alpha028 and ret_12 is: -0.008393614515944847
# Corr between alpha028 and ret_24 is: 0.004012703971595853
# Corr between alpha028 and ret_48 is: -0.004477995191472363
# Corr between alpha028 and ret_72 is: 0.0037557658886699496
# Corr between alpha028 and Close is: -0.024076965040981776

# %%
eth_data.index = pd.to_datetime(eth_data.index)

# 创建月份的分组标签（格式如 '2024-07'）
eth_data['month'] = eth_data.index.to_period('M').astype(str)

# 需要分析的收益列
ret_columns = ['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72']

# 初始化一个DataFrame用于存储相关性结果
months = sorted(eth_data['month'].unique())
correlation_matrix = pd.DataFrame(index=ret_columns, columns=months)

# 按月份计算相关性
for month in months:
    temp_df = eth_data[eth_data['month'] == month]
    for ret in ret_columns:
        corr_value = temp_df[[f"{alpha:003}", ret]].corr().iloc[0, 1]
        correlation_matrix.loc[ret, month] = corr_value

# 转换数据类型为float，方便绘图
correlation_matrix = correlation_matrix.astype(float)

# 使用heatmap可视化
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title(f'Monthly Correlation between Alpha{alpha:003} and Returns for ETH', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Return Columns', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_16204\3977908595.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   eth_data['month'] = eth_data.index.to_period('M').astype(str)
# C:\Users\elisa\AppData\Local\Temp\ipykernel_16204\3977908595.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eth_data['month'] = eth_data.index.to_period('M').astype(str)

# %%
X = sm.add_constant(eth_data[f"{alpha:03}"])
model = sm.OLS(eth_data['ret_01'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ret_01   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.002
# Date:                Sat, 26 Apr 2025   Prob (F-statistic):              0.317
# Time:                        15:55:22   Log-Likelihood:                 22950.
# No. Observations:                6667   AIC:                        -4.590e+04
# Df Residuals:                    6665   BIC:                        -4.588e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001   9.49e-05     -1.307      0.191      -0.000     6.2e-05
# 028            0.0011      0.001      1.001      0.317      -0.001       0.003
# ==============================================================================
# Omnibus:                     2866.829   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           162047.546
# Skew:                          -1.265   Prob(JB):                         0.00
# Kurtosis:                      27.020   Cond. No.                         12.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### Evaluation for ADA

# %%
ada_data = alphas.loc['ADAUSDT']
ada_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6667 entries, 2024-07-02 06:00:00+00:00 to 2025-04-06 00:00:00+00:00
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ret_01  6667 non-null   float64
#  1   ret_02  6667 non-null   float64
#  2   ret_03  6667 non-null   float64
#  3   ret_04  6667 non-null   float64
#  4   ret_05  6667 non-null   float64
#  5   ret_12  6667 non-null   float64
#  6   ret_24  6667 non-null   float64
#  7   ret_48  6667 non-null   float64
#  8   ret_72  6667 non-null   float64
#  9   Close   6667 non-null   float64
#  10  028     6667 non-null   float64
# dtypes: float64(11)
# memory usage: 625.0 KB

# %%
sns.histplot(ada_data[f"{alpha:03}"])
# Out:
# <Axes: xlabel='028', ylabel='Count'>

# %%
for c in ret_col:
    print(f"Corr between alpha{alpha:03} and {c} is:", ada_data[f"{alpha:03}"].corr(ada_data[c]))
# Out:
# Corr between alpha028 and ret_01 is: 0.009170692174639939
# Corr between alpha028 and ret_02 is: 0.011363612557513066
# Corr between alpha028 and ret_03 is: 0.015028560114377408
# Corr between alpha028 and ret_04 is: 0.0190748359781759
# Corr between alpha028 and ret_05 is: 0.01798239290856394
# Corr between alpha028 and ret_12 is: 0.02863230655832205
# Corr between alpha028 and ret_24 is: 0.03190597583347364
# Corr between alpha028 and ret_48 is: 0.05497174567147349
# Corr between alpha028 and ret_72 is: 0.041519717054054814
# Corr between alpha028 and Close is: 0.06796327059986537

# %%
ada_data.index = pd.to_datetime(ada_data.index)

# 创建月份的分组标签（格式如 '2024-07'）
ada_data['month'] = ada_data.index.to_period('M').astype(str)

# 需要分析的收益列
ret_columns = ['ret_01', 'ret_02', 'ret_03', 'ret_04', 'ret_05', 'ret_12', 'ret_24', 'ret_48', 'ret_72']

# 初始化一个DataFrame用于存储相关性结果
months = sorted(ada_data['month'].unique())
correlation_matrix = pd.DataFrame(index=ret_columns, columns=months)

# 按月份计算相关性
for month in months:
    temp_df = ada_data[ada_data['month'] == month]
    for ret in ret_columns:
        corr_value = temp_df[[f"{alpha:003}", ret]].corr().iloc[0, 1]
        correlation_matrix.loc[ret, month] = corr_value

# 转换数据类型为float，方便绘图
correlation_matrix = correlation_matrix.astype(float)

# 使用heatmap可视化
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0, linewidths=0.5)
plt.title(f'Monthly Correlation between Alpha{alpha:003} and Returns for ADA', fontsize=16)
plt.xlabel('Month', fontsize=12)
plt.ylabel('Return Columns', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_16204\2821918388.py:4: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   ada_data['month'] = ada_data.index.to_period('M').astype(str)
# C:\Users\elisa\AppData\Local\Temp\ipykernel_16204\2821918388.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ada_data['month'] = ada_data.index.to_period('M').astype(str)

# %%
X = sm.add_constant(ada_data[f"{alpha:03}"])
model = sm.OLS(ada_data['ret_01'], X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 ret_01   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5606
# Date:                Sat, 26 Apr 2025   Prob (F-statistic):              0.454
# Time:                        15:55:28   Log-Likelihood:                 19810.
# No. Observations:                6667   AIC:                        -3.962e+04
# Df Residuals:                    6665   BIC:                        -3.960e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -4.54e-06      0.000     -0.030      0.976      -0.000       0.000
# 028            0.0104      0.014      0.749      0.454      -0.017       0.037
# ==============================================================================
# Omnibus:                     2583.120   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           723754.590
# Skew:                           0.599   Prob(JB):                         0.00
# Kurtosis:                      54.029   Cond. No.                         91.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
